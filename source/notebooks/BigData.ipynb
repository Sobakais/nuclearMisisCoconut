# %%
# !pip install ultralytics==8.0.196 --quiet
import ultralytics
ultralytics.checks()

from IPython import display
display.clear_output()

# %%
HOME = "/kaggle/working/big-data-1"

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="****")
project = rf.workspace("121-hsypi").project("nuclear-huck")
version = project.version(3)
dataset = version.download("yolov8")

# %%
model = YOLO('yolov8n.pt')

# Training.
results = model.train(
   data='data={HOME}/data.yaml',
   imgsz=640,
   epochs=60,
   batch=-1,
   name='model-v1')

# %%
# !yolo task=detect mode=predict model=/kaggle/working/runs/detect/train/weights/best.pt conf=0.25 source={HOME}/test/images save=True

# %%
# !yolo task=detect mode=train model=yolov8l.pt data={HOME}/datasets/rzd_final-2/data.yaml epochs=300 imgsz=800 plots=True device = [0,1] batch=-1 #авто
