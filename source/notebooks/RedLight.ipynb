# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
HOME = "/kaggle/working/red-light-1"
#!mkdir {HOME}

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5608.0/8062.4 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="Q7CahwwFiQvxbHHRUiQF")
project = rf.workspace("121-hsypi").project("red-light-tq8yu")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory '/kaggle/working/rzd_final/datasets': No such file or directory
# [Errno 2] No such file or directory: '/kaggle/working/rzd_final/datasets'
# /kaggle/working
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# ...

# %%
# %cd {HOME}
# !ls datasets/Smoking-1/
# Out:
# [Errno 2] No such file or directory: '/kaggle/working/rzd_final'
# /kaggle/working
# ls: cannot access 'datasets/Smoking-1/': No such file or directory

# %%
# !yolo task=detect mode=train model=yolov8l.pt data={HOME}/data.yaml epochs=100 imgsz=640 plots=True device = [0,1] batch=-1
# Out:
# New https://pypi.org/project/ultralytics/8.2.2 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                        CUDA:1 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Проверяем

# %%
# !yolo task=detect mode=predict model=/kaggle/working/runs/detect/train/weights/best.pt conf=0.25 source={HOME}/test/images save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/11 /kaggle/working/red-light-1/test/images/IMG_9874_JPG.rf.8ab14d66c91d4f33846edfb6865dce32.jpg: 640x640 1 red-light, 63.7ms
# image 2/11 /kaggle/working/red-light-1/test/images/IMG_9886_JPG.rf.8c7fdba87a9d4868787e65804a9606bb.jpg: 640x640 (no detections), 62.8ms
# image 3/11 /kaggle/working/red-light-1/test/images/IMG_9976_JPG.rf.90342d56c9f0b6b16406807f8d12fe8d.jpg: 640x640 1 red-light, 61.8ms
# image 4/11 /kaggle/working/red-light-1/test/images/_-33-_mp4-21_jpg.rf.7431f2f646fdf756ed2a7daac9584edb.jpg: 640x640 2 smokes, 61.5ms
# image 5/11 /kaggle/working/red-light-1/test/images/_-33-_mp4-24_jpg.rf.f1dede1b36e28403e3ace7b4b5610e2c.jpg: 640x640 2 smokes, 49.4ms
# image 6/11 /kaggle/working/red-light-1/test/images/_-33-_mp4-27_jpg.rf.5429eef0967cd0ee2cb0a4b1ec24d901.jpg: 640x640 1 smoke, 44.2ms
# ...

# %%
# !yolo task=detect mode=val model=/kaggle/working/runs/detect/train/weights/best.pt data={HOME}/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /kaggle/working/red-light-1/valid/labels.cache... 20 images, 0 bac
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 22, len(boxes) = 29. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         20         29      0.581      0.546      0.578      0.305
#              red-light         20         13      0.723      0.603      0.706      0.382
#                  smoke         20         16      0.438      0.488      0.451      0.227
# Speed: 4.3ms preprocess, 62.4ms inference, 0.0ms loss, 25.4ms postprocess per image
# Results saved to runs/detect/val
# ...
